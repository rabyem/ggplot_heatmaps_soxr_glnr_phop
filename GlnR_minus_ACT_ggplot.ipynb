# %%
import pandas as pd
df = pd.read_csv("GlnR Transcriptomics Data -ACT.csv", index_col= 'Locus_tag')
df
# Out:
#                     18          20          22          26          30  \
# Locus_tag
# SCO4159     137.413700  136.499865  134.654113   62.670134   77.967219
# SCO2198_A   642.520261  640.366462  697.287581  117.663128  116.245237
# SCO5583_A    99.083960   93.529790  111.494336   14.403009    9.442913
# SCO5584_A   184.197174  134.347311  183.890206   21.420243   13.931832
# SCO5585_A    33.462992   23.969531   29.886670    3.602574    3.124284
# ...                ...         ...         ...         ...         ...
# SCO6148_R   110.605217  109.887945   85.595487   87.963882   95.385017
# SCO1864_R   245.517361  183.952215  198.210681  104.054702  155.567493
# SCO1865_R    76.368136   64.846048   76.952371   48.937912   69.955629
# SCO1866_R   782.648721  650.099256  626.820264  288.546884  482.619413
# SCO1867_R  1020.294033  746.857070  783.261091  358.164541  471.117670
#
#                    32          34          38          44          50
# Locus_tag
# SCO4159     70.618428   64.517044   77.046670   47.319638   64.581292
# SCO2198_A  106.163343  128.348404  204.585789  147.904874  234.870479
# SCO5583_A    6.435247    5.800684    5.060663    4.613126    6.341441
# SCO5584_A    9.588802    8.178584    6.543176    8.159821    8.776624
# SCO5585_A    2.116954    2.411953    2.308132    1.838237    2.391762
# ...               ...         ...         ...         ...         ...
# SCO6148_R   68.485261   93.574886   96.844262   77.162592   68.534105
# SCO1864_R  134.121737  121.946560   99.237701   37.588843   35.546901
# SCO1865_R   60.565499   63.091534   52.399607   26.159066   31.652671
# SCO1866_R  387.112447  461.521475  380.468937  149.004541  150.339339
# SCO1867_R  454.107707  529.392796  500.962718  193.219297  240.169287
#
# [76 rows x 10 columns]

# %%
df1 = df.stack().rename_axis(('a', 'b')).reset_index(name='val')
df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2 = df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2
# Out:
#      Locus tag Time       value
# 0      SCO4159   18  137.413700
# 1      SCO4159   20  136.499865
# 2      SCO4159   22  134.654113
# 3      SCO4159   26   62.670134
# 4      SCO4159   30   77.967219
# ..         ...  ...         ...
# 755  SCO1867_R   32  454.107707
# 756  SCO1867_R   34  529.392796
# 757  SCO1867_R   38  500.962718
# 758  SCO1867_R   44  193.219297
# 759  SCO1867_R   50  240.169287
#
# [760 rows x 3 columns]

# %%
from plotnine import *

# %%
colors = ("black", "white", "red")
lims= (0,50)
b = (5,25,50)
a = ggplot(df2, aes(x='Time', y='Locus tag')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(5,25,50),labels=("5", "25", "50"))
print(a + ggtitle('GLNR REGULON M1146 +ACT') + labs(y="Locus tag", x = "Time"))
# Out:
# <ggplot: (-9223371924280526428)>

# %%
df3 = pd.read_csv("GlnR Transcriptomics Data -ACT.csv", index_col= 'Locus_tag')
df4 = df3.transpose()
corr = df4.corr(method='pearson')
df5 = corr
df5
# Out:
# Locus_tag   SCO4159  SCO2198_A  SCO5583_A  SCO5584_A  SCO5585_A  SCO2210_A  \
# Locus_tag
# SCO4159    1.000000   0.954448   0.963692   0.952516   0.957783   0.960067
# SCO2198_A  0.954448   1.000000   0.979938   0.969381   0.969155   0.981347
# SCO5583_A  0.963692   0.979938   1.000000   0.992185   0.987153   0.999441
# SCO5584_A  0.952516   0.969381   0.992185   1.000000   0.997520   0.990068
# SCO5585_A  0.957783   0.969155   0.987153   0.997520   1.000000   0.983403
# ...             ...        ...        ...        ...        ...        ...
# SCO6148_R  0.642522   0.526995   0.547092   0.541079   0.575271   0.532071
# SCO1864_R  0.871535   0.719322   0.803378   0.819333   0.828849   0.791911
# SCO1865_R  0.740243   0.545422   0.639974   0.648617   0.649734   0.632487
# SCO1866_R  0.896725   0.759688   0.816311   0.824247   0.839542   0.806479
# SCO1867_R  0.920031   0.821476   0.857534   0.877923   0.894879   0.848752
#
# Locus_tag  SCO2487_A  SCO2488_A  SCO2400_A  SCO1863_A  ...  SCO2789_R  \
# Locus_tag                                              ...
# SCO4159     0.966202   0.856013   0.532043   0.859590  ...   0.847935
# SCO2198_A   0.948263   0.888517   0.546786   0.802720  ...   0.747739
# SCO5583_A   0.985751   0.913780   0.539856   0.822384  ...   0.779032
# SCO5584_A   0.989417   0.906582   0.538686   0.799243  ...   0.825619
# SCO5585_A   0.986942   0.886697   0.540147   0.812750  ...   0.846664
# ...              ...        ...        ...        ...  ...        ...
# SCO6148_R   0.582041   0.376973   0.591200   0.599166  ...   0.696774
# SCO1864_R   0.870450   0.732273   0.480238   0.792352  ...   0.920020
# SCO1865_R   0.724000   0.674604   0.420025   0.707370  ...   0.828115
# SCO1866_R   0.867590   0.756746   0.568502   0.842663  ...   0.929258
# SCO1867_R   0.896802   0.790620   0.578846   0.813783  ...   0.970164
#
# Locus_tag  SCO3874_R  SCO4164_R  SCO4471_R  SCO6102_R  SCO6148_R  SCO1864_R  \
# Locus_tag
# SCO4159    -0.236921   0.316078   0.897102   0.770345   0.642522   0.871535
# SCO2198_A  -0.088801   0.068664   0.815420   0.624521   0.526995   0.719322
# SCO5583_A  -0.235751   0.133514   0.868827   0.682358   0.547092   0.803378
# SCO5584_A  -0.233492   0.141307   0.824081   0.703109   0.541079   0.819333
# SCO5585_A  -0.217785   0.171027   0.810788   0.731234   0.575271   0.828849
# ...              ...        ...        ...        ...        ...        ...
# SCO6148_R  -0.266583   0.758569   0.638049   0.875970   1.000000   0.688521
# SCO1864_R  -0.520512   0.611118   0.819688   0.890622   0.688521   1.000000
# SCO1865_R  -0.546390   0.701616   0.771117   0.770659   0.599579   0.939963
# SCO1866_R  -0.449147   0.642192   0.831456   0.904027   0.767029   0.979640
# SCO1867_R  -0.389865   0.540683   0.802237   0.880589   0.734487   0.953994
#
# Locus_tag  SCO1865_R  SCO1866_R  SCO1867_R
# Locus_tag
# SCO4159     0.740243   0.896725   0.920031
# SCO2198_A   0.545422   0.759688   0.821476
# SCO5583_A   0.639974   0.816311   0.857534
# SCO5584_A   0.648617   0.824247   0.877923
# SCO5585_A   0.649734   0.839542   0.894879
# ...              ...        ...        ...
# SCO6148_R   0.599579   0.767029   0.734487
# SCO1864_R   0.939963   0.979640   0.953994
# SCO1865_R   1.000000   0.921361   0.859473
# SCO1866_R   0.921361   1.000000   0.977278
# SCO1867_R   0.859473   0.977278   1.000000
#
# [76 rows x 76 columns]

# %%
df6 = df5.stack().rename_axis(('a', 'b')).reset_index(name='val')
df7 = df6.rename(columns={"a": "x", "b": "y", "val": "value"})
df7
# Out:
#               x          y     value
# 0       SCO4159    SCO4159  1.000000
# 1       SCO4159  SCO2198_A  0.954448
# 2       SCO4159  SCO5583_A  0.963692
# 3       SCO4159  SCO5584_A  0.952516
# 4       SCO4159  SCO5585_A  0.957783
# ...         ...        ...       ...
# 5771  SCO1867_R  SCO6148_R  0.734487
# 5772  SCO1867_R  SCO1864_R  0.953994
# 5773  SCO1867_R  SCO1865_R  0.859473
# 5774  SCO1867_R  SCO1866_R  0.977278
# 5775  SCO1867_R  SCO1867_R  1.000000
#
# [5776 rows x 3 columns]

# %%
colors = ("blue", "cornflowerblue", "white", "pink", "red")
lims=(-1,1)
b = (-1, -0.5, 0, 0.5, 1)
a = ggplot(df7, aes(x='x', y='y')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(-1,-0.5,0,0.5,1),labels=("-1", "-0.5", "0", "0.5", "1"))

# %%
a + theme(axis_text_x = element_text(angle = 90, hjust=1))
# Out:
# <ggplot: (-9223371924280485224)>

# %%
b = a + theme(axis_text_x = element_text(angle = 90, hjust=1))
b + ggtitle('GLNR REGULON M1146 -ACT') + labs(y="Locus tag", x = "Locus tag")
# Out:
# <ggplot: (-9223371924278332008)>
