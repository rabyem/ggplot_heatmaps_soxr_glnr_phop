# %%
import pandas as pd
df = pd.read_csv("PhoP Transcriptomics Data TOPCAPI.csv", index_col= 'Locus_tag')
df
# Out:
#               21     24     28    45    48     52    68    72    76     92
# Locus_tag
# SCO0033_A    0.3    0.2    1.2  19.1   6.6    8.5  23.4  14.0  14.4    2.4
# SCO0034_A    0.3    0.3    0.9   0.7   0.2    2.2   2.8   2.4   1.2    1.1
# SCO0216_A   26.7  164.6    8.6  14.1   5.9    7.6   3.9   2.2   2.0    1.6
# SCO0217_A   17.0  126.5    4.1   8.4   3.7    6.2   4.3   1.8   1.3    1.1
# SCO0379_A   71.7   70.5   48.5  32.4  37.8   38.5  54.5  53.9  24.2  746.4
# ...          ...    ...    ...   ...   ...    ...   ...   ...   ...    ...
# SCO5478_R  463.3  453.1   34.8  18.1  28.5   47.1  66.9  66.3  44.3   59.0
# SCO5479_R  284.0  391.7   26.6  15.3  18.8   32.4  47.5  50.3  27.8   35.0
# SCO5480_R  151.6  195.4   12.3   8.4  10.5   17.2  28.0  26.1  13.2   13.8
# SCO5583_R    4.3    2.9    2.0  41.3  67.1  114.2  77.7  94.9  42.4    3.1
# SCO5822_R  147.8  124.4  104.5  31.8  39.1   51.0  43.7  39.2  25.5   30.0
#
# [111 rows x 10 columns]

# %%
df1 = df.stack().rename_axis(('a', 'b')).reset_index(name='val')
df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2 = df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2
# Out:
#       Locus tag Time  value
# 0     SCO0033_A   21    0.3
# 1     SCO0033_A   24    0.2
# 2     SCO0033_A   28    1.2
# 3     SCO0033_A   45   19.1
# 4     SCO0033_A   48    6.6
# ...         ...  ...    ...
# 1105  SCO5822_R   52   51.0
# 1106  SCO5822_R   68   43.7
# 1107  SCO5822_R   72   39.2
# 1108  SCO5822_R   76   25.5
# 1109  SCO5822_R   92   30.0
#
# [1110 rows x 3 columns]

# %%
from plotnine import *

# %%
colors = ("black", "white", "red")
lims= (0,50)
b = (5,25,50)
a = ggplot(df2, aes(x='Time', y='Locus tag')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(5,25,50),labels=("5", "25", "50"))
print(a + ggtitle('PHOP REGULON M1146 TOPCAPI') + labs(y="Locus tag", x = "Time"))
# Out:
# <ggplot: (-9223371893108520976)>

# %%
df3 = pd.read_csv("PhoP Transcriptomics Data TOPCAPI.csv", index_col= 'Locus_tag')
df4 = df3.transpose()
corr = df4.corr(method='pearson')
df5 = corr
df5
# Out:
# Locus_tag  SCO0033_A  SCO0034_A  SCO0216_A  SCO0217_A  SCO0379_A  SCO1196_A  \
# Locus_tag
# SCO0033_A   1.000000   0.631473  -0.414221  -0.396961  -0.310141   0.679129
# SCO0034_A   0.631473   1.000000  -0.409682  -0.382000  -0.049374   0.738026
# SCO0216_A  -0.414221  -0.409682   1.000000   0.999220  -0.114943  -0.172246
# SCO0217_A  -0.396961  -0.382000   0.999220   1.000000  -0.108948  -0.146550
# SCO0379_A  -0.310141  -0.049374  -0.114943  -0.108948   1.000000   0.013662
# ...              ...        ...        ...        ...        ...        ...
# SCO5478_R  -0.538497  -0.444624   0.739536   0.726047  -0.081432  -0.209556
# SCO5479_R  -0.523012  -0.435254   0.860874   0.851307  -0.097716  -0.188886
# SCO5480_R  -0.508203  -0.426457   0.840409   0.830280  -0.119279  -0.177320
# SCO5583_R   0.607559   0.710300  -0.402066  -0.378873  -0.375584   0.358074
# SCO5822_R  -0.669022  -0.458634   0.580390   0.557899  -0.210493  -0.321581
#
# Locus_tag  SCO1393_A  SCO1394_A  SCO1565_A  SCO1845_A  ...  SCO5372_R  \
# Locus_tag                                              ...
# SCO0033_A  -0.582240   0.905747   0.814793   0.275435  ...  -0.595637
# SCO0034_A  -0.154276   0.797994   0.761918   0.014558  ...  -0.472306
# SCO0216_A   0.374877  -0.475512  -0.246260  -0.234439  ...   0.822927
# SCO0217_A   0.363216  -0.451318  -0.221594  -0.243859  ...   0.811861
# SCO0379_A   0.216526  -0.298308  -0.188774  -0.578193  ...   0.063515
# ...              ...        ...        ...        ...  ...        ...
# SCO5478_R   0.714104  -0.608901  -0.306295  -0.148140  ...   0.974773
# SCO5479_R   0.654934  -0.585149  -0.283720  -0.196306  ...   0.983758
# SCO5480_R   0.666227  -0.571560  -0.268729  -0.166190  ...   0.980896
# SCO5583_R  -0.447406   0.707189   0.498485   0.509528  ...  -0.558611
# SCO5822_R   0.808078  -0.641262  -0.410664  -0.009284  ...   0.807385
#
# Locus_tag  SCO5373_R  SCO5374_R  SCO5476_R  SCO5477_R  SCO5478_R  SCO5479_R  \
# Locus_tag
# SCO0033_A  -0.613692  -0.505830  -0.540517  -0.558463  -0.538497  -0.523012
# SCO0034_A  -0.484792  -0.339832  -0.351891  -0.475711  -0.444624  -0.435254
# SCO0216_A   0.539184   0.670928   0.769547   0.697201   0.739536   0.860874
# SCO0217_A   0.521028   0.657426   0.760129   0.681601   0.726047   0.851307
# SCO0379_A   0.127310  -0.109750  -0.076142  -0.061512  -0.081432  -0.097716
# ...              ...        ...        ...        ...        ...        ...
# SCO5478_R   0.946129   0.932273   0.988412   0.996797   1.000000   0.978311
# SCO5479_R   0.873062   0.904667   0.981598   0.961352   0.978311   1.000000
# SCO5480_R   0.883842   0.917276   0.986057   0.969765   0.984915   0.998787
# SCO5583_R  -0.569739  -0.405075  -0.447039  -0.512581  -0.494766  -0.481926
# SCO5822_R   0.817944   0.889767   0.852852   0.855013   0.849073   0.813051
#
# Locus_tag  SCO5480_R  SCO5583_R  SCO5822_R
# Locus_tag
# SCO0033_A  -0.508203   0.607559  -0.669022
# SCO0034_A  -0.426457   0.710300  -0.458634
# SCO0216_A   0.840409  -0.402066   0.580390
# SCO0217_A   0.830280  -0.378873   0.557899
# SCO0379_A  -0.119279  -0.375584  -0.210493
# ...              ...        ...        ...
# SCO5478_R   0.984915  -0.494766   0.849073
# SCO5479_R   0.998787  -0.481926   0.813051
# SCO5480_R   1.000000  -0.467633   0.822537
# SCO5583_R  -0.467633   1.000000  -0.559047
# SCO5822_R   0.822537  -0.559047   1.000000
#
# [111 rows x 111 columns]

# %%
df6 = df5.stack().rename_axis(('a', 'b')).reset_index(name='val')
df7 = df6.rename(columns={"a": "x", "b": "y", "val": "value"})
df7
# Out:
#                x          y     value
# 0      SCO0033_A  SCO0033_A  1.000000
# 1      SCO0033_A  SCO0034_A  0.631473
# 2      SCO0033_A  SCO0216_A -0.414221
# 3      SCO0033_A  SCO0217_A -0.396961
# 4      SCO0033_A  SCO0379_A -0.310141
# ...          ...        ...       ...
# 12316  SCO5822_R  SCO5478_R  0.849073
# 12317  SCO5822_R  SCO5479_R  0.813051
# 12318  SCO5822_R  SCO5480_R  0.822537
# 12319  SCO5822_R  SCO5583_R -0.559047
# 12320  SCO5822_R  SCO5822_R  1.000000
#
# [12321 rows x 3 columns]

# %%
colors = ("blue", "cornflowerblue", "white", "pink", "red")
lims=(-1,1)
b = (-1, -0.5, 0, 0.5, 1)
a = ggplot(df7, aes(x='x', y='y')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(-1,-0.5,0,0.5,1),labels=("-1", "-0.5", "0", "0.5", "1"))

# %%
a + theme(axis_text_x = element_text(angle = 90, hjust=1))
# Out:
# <ggplot: (-9223371893108025012)>

# %%
b = a + theme(axis_text_x = element_text(angle = 90, hjust=1))
b + ggtitle('PHOP REGULON M1146 TOPCAPI') + labs(y="Locus tag", x = "Locus tag")
# Out:
# <ggplot: (-9223371893108021320)>
