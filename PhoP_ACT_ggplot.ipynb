# %%
import pandas as pd
df = pd.read_csv("PhoP Transcriptomics Data ACT.csv", index_col= 'Locus_tag')
df
# Out:
#                    18          20          22          26          30  \
# Locus_tag
# SCO0033_A    0.864064    1.124709    1.328288    1.258114    1.576399
# SCO0034_A    2.348653    2.576510    2.261109    4.157326    3.242515
# SCO0216_A   46.440131   62.906719   63.032541  150.586078  226.912632
# SCO0217_A   20.916829   29.095781   26.199468   87.085684  159.228935
# SCO0379_A   53.989062  100.415949  204.055836  141.265776  159.394638
# ...               ...         ...         ...         ...         ...
# SCO5478_R  136.608978   89.671570  116.654221   75.517121  106.425141
# SCO5479_R   96.056608   70.616825   84.142915   53.815534   79.868396
# SCO5480_R   48.222725   35.666781   42.992921   28.366103   42.222663
# SCO5583_R   99.083960   93.529790  111.494336   14.403009    9.442913
# SCO5822_R   76.902521   70.403093   71.282425   54.282721   61.957117
#
#                    32          34          38          44          50
# Locus_tag
# SCO0033_A    0.795653    1.503097    1.203847   11.686097    7.368033
# SCO0034_A    1.580155    3.360655    4.282987    3.925436    4.598880
# SCO0216_A  165.018056  139.151253  174.987600   66.891731   92.256308
# SCO0217_A  122.441489   94.683070  117.890984   39.016413   46.459053
# SCO0379_A  129.150819  140.520814  173.130249  276.108604  501.058341
# ...               ...         ...         ...         ...         ...
# SCO5478_R   91.921484  109.448346  119.195261  123.559303  123.261282
# SCO5479_R   59.258886   78.966201   85.684383   88.175117   78.625667
# SCO5480_R   34.773396   42.025087   44.086241   47.833213   37.817755
# SCO5583_R    6.435247    5.800684    5.060663    4.613126    6.341441
# SCO5822_R   57.492635   59.404791   62.124331   55.113703   40.080638
#
# [109 rows x 10 columns]

# %%
df1 = df.stack().rename_axis(('a', 'b')).reset_index(name='val')
df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2 = df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2
# Out:
#       Locus tag Time      value
# 0     SCO0033_A   18   0.864064
# 1     SCO0033_A   20   1.124709
# 2     SCO0033_A   22   1.328288
# 3     SCO0033_A   26   1.258114
# 4     SCO0033_A   30   1.576399
# ...         ...  ...        ...
# 1085  SCO5822_R   32  57.492635
# 1086  SCO5822_R   34  59.404791
# 1087  SCO5822_R   38  62.124331
# 1088  SCO5822_R   44  55.113703
# 1089  SCO5822_R   50  40.080638
#
# [1090 rows x 3 columns]

# %%
from plotnine import *

# %%
colors = ("black", "white", "red")
lims= (0,50)
b = (5,25,50)
a = ggplot(df2, aes(x='Time', y='Locus tag')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(5,25,50),labels=("5", "25", "50"))
print(a + ggtitle('PHOP REGULON M1146 +ACT') + labs(y="Locus tag", x = "Time"))
# Out:
# <ggplot: (-9223371894202415928)>

# %%
df3 = pd.read_csv("PhoP Transcriptomics Data ACT.csv", index_col= 'Locus_tag')
df4 = df3.transpose()
corr = df4.corr(method='pearson')
df5 = corr
df5
# Out:
# Locus_tag  SCO0033_A  SCO0034_A  SCO0216_A  SCO0217_A  SCO0379_A  SCO1196_A  \
# Locus_tag
# SCO0033_A   1.000000   0.500166  -0.327811  -0.316767   0.705641   0.970410
# SCO0034_A   0.500166   1.000000   0.177585   0.096342   0.598645   0.381444
# SCO0216_A  -0.327811   0.177585   1.000000   0.990103  -0.121143  -0.340334
# SCO0217_A  -0.316767   0.096342   0.990103   1.000000  -0.163972  -0.310097
# SCO0379_A   0.705641   0.598645  -0.121143  -0.163972   1.000000   0.527558
# ...              ...        ...        ...        ...        ...        ...
# SCO5478_R   0.380954   0.108396  -0.394579  -0.354861   0.301806   0.354301
# SCO5479_R   0.282714   0.064607  -0.388521  -0.352105   0.098314   0.296193
# SCO5480_R   0.306578  -0.043066  -0.284564  -0.218737  -0.005173   0.371619
# SCO5583_R  -0.352347  -0.569791  -0.674321  -0.680512  -0.368492  -0.309073
# SCO5822_R  -0.560901  -0.655428  -0.285293  -0.248715  -0.792187  -0.416038
#
# Locus_tag  SCO1394_A  SCO1565_A  SCO1845_A  SCO1906_A  ...  SCO5372_R  \
# Locus_tag                                              ...
# SCO0033_A   0.989088   0.984592  -0.721572   0.935068  ...  -0.733008
# SCO0034_A   0.494613   0.430199  -0.737572   0.249090  ...  -0.385238
# SCO0216_A  -0.313086  -0.341638  -0.226455  -0.426452  ...   0.094718
# SCO0217_A  -0.300810  -0.317289  -0.200982  -0.389408  ...   0.091901
# SCO0379_A   0.774608   0.582272  -0.701156   0.435965  ...  -0.662138
# ...              ...        ...        ...        ...  ...        ...
# SCO5478_R   0.416054   0.375184   0.058833   0.345026  ...   0.055536
# SCO5479_R   0.273529   0.300209   0.213629   0.312791  ...   0.204658
# SCO5480_R   0.289385   0.358688   0.168300   0.390583  ...   0.125167
# SCO5583_R  -0.380995  -0.328068   0.815107  -0.173925  ...   0.490299
# SCO5822_R  -0.622456  -0.463071   0.908179  -0.292411  ...   0.699882
#
# Locus_tag  SCO5373_R  SCO5374_R  SCO5476_R  SCO5477_R  SCO5478_R  SCO5479_R  \
# Locus_tag
# SCO0033_A  -0.565430  -0.707664  -0.277351   0.573790   0.380954   0.282714
# SCO0034_A   0.199146  -0.701074  -0.629103   0.526617   0.108396   0.064607
# SCO0216_A   0.289110  -0.069261  -0.490370  -0.200827  -0.394579  -0.388521
# SCO0217_A   0.228147  -0.035050  -0.435720  -0.206091  -0.354861  -0.352105
# SCO0379_A  -0.169768  -0.797957  -0.466312   0.566098   0.301806   0.098314
# ...              ...        ...        ...        ...        ...        ...
# SCO5478_R   0.186051  -0.038116   0.505907   0.871199   1.000000   0.939672
# SCO5479_R   0.254237   0.160784   0.644405   0.829797   0.939672   1.000000
# SCO5480_R   0.081587   0.154015   0.652736   0.755097   0.891634   0.956663
# SCO5583_R   0.149156   0.661362   0.795687  -0.117657   0.169014   0.299280
# SCO5822_R   0.246926   0.874540   0.878972  -0.183536   0.139891   0.364017
#
# Locus_tag  SCO5480_R  SCO5583_R  SCO5822_R
# Locus_tag
# SCO0033_A   0.306578  -0.352347  -0.560901
# SCO0034_A  -0.043066  -0.569791  -0.655428
# SCO0216_A  -0.284564  -0.674321  -0.285293
# SCO0217_A  -0.218737  -0.680512  -0.248715
# SCO0379_A  -0.005173  -0.368492  -0.792187
# ...              ...        ...        ...
# SCO5478_R   0.891634   0.169014   0.139891
# SCO5479_R   0.956663   0.299280   0.364017
# SCO5480_R   1.000000   0.185772   0.377491
# SCO5583_R   0.185772   1.000000   0.783400
# SCO5822_R   0.377491   0.783400   1.000000
#
# [109 rows x 109 columns]

# %%
df6 = df5.stack().rename_axis(('a', 'b')).reset_index(name='val')
df7 = df6.rename(columns={"a": "x", "b": "y", "val": "value"})
df7
# Out:
#                x          y     value
# 0      SCO0033_A  SCO0033_A  1.000000
# 1      SCO0033_A  SCO0034_A  0.500166
# 2      SCO0033_A  SCO0216_A -0.327811
# 3      SCO0033_A  SCO0217_A -0.316767
# 4      SCO0033_A  SCO0379_A  0.705641
# ...          ...        ...       ...
# 11876  SCO5822_R  SCO5478_R  0.139891
# 11877  SCO5822_R  SCO5479_R  0.364017
# 11878  SCO5822_R  SCO5480_R  0.377491
# 11879  SCO5822_R  SCO5583_R  0.783400
# 11880  SCO5822_R  SCO5822_R  1.000000
#
# [11881 rows x 3 columns]

# %%
colors = ("blue", "cornflowerblue", "white", "pink", "red")
lims=(-1,1)
b = (-1, -0.5, 0, 0.5, 1)
a = ggplot(df7, aes(x='x', y='y')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(-1,-0.5,0,0.5,1),labels=("-1", "-0.5", "0", "0.5", "1"))

# %%
a + theme(axis_text_x = element_text(angle = 90, hjust=1))
# Out:
# <ggplot: (-9223371895253755900)>

# %%
b = a + theme(axis_text_x = element_text(angle = 90, hjust=1))
b + ggtitle('PHOP REGULON M1146 +ACT') + labs(y="Locus tag", x = "Locus tag")
# Out:
# <ggplot: (-9223371895253756768)>
