# %%
import pandas as pd
df = pd.read_csv("SoxR Transcriptomics Data -ACT.csv", index_col= 'Locus_tag')
df
# Out:
#                   18         20         22         26         30         32  \
# Locus_tag
# SCO0319_A   1.105248   3.268412   5.054244   1.956389   3.051779   3.186867
# SCO0320_A  19.159191  37.321821  40.785830  14.968711  22.871691  22.516490
# SCO0321_A  21.922768  34.189429  40.604118  11.214366  14.856411  17.606568
# SCO1178_A  40.362029  67.273054  89.841404  38.308987  45.678466  47.795918
# SCO1697    20.521055  21.182376  16.444430  12.073042  14.738705  15.083295
# SCO1734_A   1.111096   0.753090   0.886709   0.672832   1.453228   1.214044
# SCO1909_A  18.223067  47.391079  69.845279  38.363269  40.176108  42.239487
# SCO2476_A   4.293236  10.624039  13.129021   7.748421  10.603998   7.063364
# SCO2477_A   7.584190  19.113785  27.468943   8.661095  13.557067  11.427905
# SCO2478_A  21.622515  54.319327  98.058306  40.630553  47.280023  45.331552
# SCO4021_A   5.606942   5.940376   4.393012   2.709960   3.646099   3.130211
# SCO4264_A  37.090595  42.745509  23.465806  25.842406  37.131966  35.621357
# SCO4265_A  41.670978  63.194736  59.668159  22.216397  33.827224  35.150380
# SCO4266_A  19.536192  36.121159  38.929800  15.425755  24.290654  23.360610
# SCO7008_A   5.277683  11.585782  18.161229  10.258432  11.506680   9.939625
#
#                   34         38         44         50
# Locus_tag
# SCO0319_A   1.878013   3.924967   4.008956   3.199221
# SCO0320_A  25.949358  22.370833  27.910451  38.471646
# SCO0321_A  14.407431  14.697930  16.530183  19.694627
# SCO1178_A  41.896161  47.729010  40.891347  51.827382
# SCO1697    12.697928  11.680875  10.781661  10.088453
# SCO1734_A   1.176700   0.959773   0.973229   1.568246
# SCO1909_A  33.891347  34.156920  27.688973  39.922484
# SCO2476_A   7.453065   5.453719   5.172846   6.385542
# SCO2477_A  11.749164   9.439479   6.211793  13.121805
# SCO2478_A  46.380463  49.500477  32.248912  48.641219
# SCO4021_A   2.912567   2.919731   2.672637   3.016408
# SCO4264_A  16.745530  10.163283   6.796397   4.507494
# SCO4265_A  29.539087  26.263264  30.146710  33.325220
# SCO4266_A  19.475353  21.894041  23.865750  27.638531
# SCO7008_A   8.226882   8.771558   8.253103  12.643322

# %%
df1 = df.stack().rename_axis(('a', 'b')).reset_index(name='val')
df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2 = df1.rename(columns={"a": "Locus tag", "b": "Time", "val": "value"})
df2
# Out:
#      Locus tag Time      value
# 0    SCO0319_A   18   1.105248
# 1    SCO0319_A   20   3.268412
# 2    SCO0319_A   22   5.054244
# 3    SCO0319_A   26   1.956389
# 4    SCO0319_A   30   3.051779
# ..         ...  ...        ...
# 145  SCO7008_A   32   9.939625
# 146  SCO7008_A   34   8.226882
# 147  SCO7008_A   38   8.771558
# 148  SCO7008_A   44   8.253103
# 149  SCO7008_A   50  12.643322
#
# [150 rows x 3 columns]

# %%
from plotnine import *

# %%
colors = ("black", "white", "red")
lims= (0,50)
b = (5,25,50)
a = ggplot(df2, aes(x='Time', y='Locus tag')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(5,25,50),labels=("5", "25", "50"))
print(a + ggtitle('SOXR REGULON M1146 -ACT') + labs(y="Locus tag", x = "Time"))
# Out:
# <ggplot: (-9223371879078238340)>

# %%
df3 = pd.read_csv("SoxR Transcriptomics Data -ACT.csv", index_col= 'Locus_tag')
df4 = df3.transpose()
corr = df4.corr(method='pearson')
df5 = corr
df5
# Out:
# Locus_tag  SCO0319_A  SCO0320_A  SCO0321_A  SCO1178_A   SCO1697  SCO1734_A  \
# Locus_tag
# SCO0319_A   1.000000   0.625206   0.488843   0.683247 -0.202235  -0.100845
# SCO0320_A   0.625206   1.000000   0.768736   0.794709  0.114292   0.107519
# SCO0321_A   0.488843   0.768736   1.000000   0.927876  0.617760  -0.281541
# SCO1178_A   0.683247   0.794709   0.927876   1.000000  0.372997  -0.228584
# SCO1697    -0.202235   0.114292   0.617760   0.372997  1.000000  -0.280245
# SCO1734_A  -0.100845   0.107519  -0.281541  -0.228584 -0.280245   1.000000
# SCO1909_A   0.681096   0.646458   0.693276   0.890167  0.117531  -0.185194
# SCO2476_A   0.464719   0.516099   0.644269   0.778112  0.322226  -0.172244
# SCO2477_A   0.565682   0.753191   0.863148   0.960881  0.377833  -0.129762
# SCO2478_A   0.716450   0.669915   0.707456   0.913636  0.073796  -0.165861
# SCO4021_A  -0.132098   0.293451   0.701708   0.445509  0.953586  -0.225989
# SCO4264_A  -0.314186  -0.192668   0.292575   0.141743  0.842254  -0.183727
# SCO4265_A   0.350798   0.697051   0.960170   0.834743  0.767766  -0.245964
# SCO4266_A   0.703094   0.898308   0.915407   0.930343  0.395160  -0.096118
# SCO7008_A   0.703082   0.706844   0.651109   0.855036 -0.007604  -0.036714
#
# Locus_tag  SCO1909_A  SCO2476_A  SCO2477_A  SCO2478_A  SCO4021_A  SCO4264_A  \
# Locus_tag
# SCO0319_A   0.681096   0.464719   0.565682   0.716450  -0.132098  -0.314186
# SCO0320_A   0.646458   0.516099   0.753191   0.669915   0.293451  -0.192668
# SCO0321_A   0.693276   0.644269   0.863148   0.707456   0.701708   0.292575
# SCO1178_A   0.890167   0.778112   0.960881   0.913636   0.445509   0.141743
# SCO1697     0.117531   0.322226   0.377833   0.073796   0.953586   0.842254
# SCO1734_A  -0.185194  -0.172244  -0.129762  -0.165861  -0.225989  -0.183727
# SCO1909_A   1.000000   0.884442   0.924968   0.959409   0.122747   0.118621
# SCO2476_A   0.884442   1.000000   0.891880   0.822459   0.306520   0.395332
# SCO2477_A   0.924968   0.891880   1.000000   0.927426   0.425059   0.239611
# SCO2478_A   0.959409   0.822459   0.927426   1.000000   0.107450  -0.023308
# SCO4021_A   0.122747   0.306520   0.425059   0.107450   1.000000   0.689837
# SCO4264_A   0.118621   0.395332   0.239611  -0.023308   0.689837   1.000000
# SCO4265_A   0.592207   0.641381   0.802438   0.569419   0.825408   0.490011
# SCO4266_A   0.773626   0.709266   0.880472   0.765170   0.506230   0.145102
# SCO7008_A   0.958987   0.838580   0.885613   0.924981   0.060534  -0.019808
#
# Locus_tag  SCO4265_A  SCO4266_A  SCO7008_A
# Locus_tag
# SCO0319_A   0.350798   0.703094   0.703082
# SCO0320_A   0.697051   0.898308   0.706844
# SCO0321_A   0.960170   0.915407   0.651109
# SCO1178_A   0.834743   0.930343   0.855036
# SCO1697     0.767766   0.395160  -0.007604
# SCO1734_A  -0.245964  -0.096118  -0.036714
# SCO1909_A   0.592207   0.773626   0.958987
# SCO2476_A   0.641381   0.709266   0.838580
# SCO2477_A   0.802438   0.880472   0.885613
# SCO2478_A   0.569419   0.765170   0.924981
# SCO4021_A   0.825408   0.506230   0.060534
# SCO4264_A   0.490011   0.145102  -0.019808
# SCO4265_A   1.000000   0.881103   0.525700
# SCO4266_A   0.881103   1.000000   0.770455
# SCO7008_A   0.525700   0.770455   1.000000

# %%
df6 = df5.stack().rename_axis(('a', 'b')).reset_index(name='val')
df7 = df6.rename(columns={"a": "x", "b": "y", "val": "value"})
df7
# Out:
#              x          y     value
# 0    SCO0319_A  SCO0319_A  1.000000
# 1    SCO0319_A  SCO0320_A  0.625206
# 2    SCO0319_A  SCO0321_A  0.488843
# 3    SCO0319_A  SCO1178_A  0.683247
# 4    SCO0319_A    SCO1697 -0.202235
# ..         ...        ...       ...
# 220  SCO7008_A  SCO4021_A  0.060534
# 221  SCO7008_A  SCO4264_A -0.019808
# 222  SCO7008_A  SCO4265_A  0.525700
# 223  SCO7008_A  SCO4266_A  0.770455
# 224  SCO7008_A  SCO7008_A  1.000000
#
# [225 rows x 3 columns]

# %%
colors = ("blue", "cornflowerblue", "white", "pink", "red")
lims=(-1,1)
b = (-1, -0.5, 0, 0.5, 1)
a = ggplot(df7, aes(x='x', y='y')) + geom_tile(aes(fill = 'value'))+ scale_fill_gradientn(limits= lims,colors= colors, breaks=(-1,-0.5,0,0.5,1),labels=("-1", "-0.5", "0", "0.5", "1"))

# %%
a + theme(axis_text_x = element_text(angle = 90, hjust=1))
b = a + theme(axis_text_x = element_text(angle = 90, hjust=1))
b + ggtitle('SOXR REGULON M1146 -ACT') + labs(y="Locus tag", x = "Locus tag")
# Out:
# <ggplot: (-9223371879075912972)>
